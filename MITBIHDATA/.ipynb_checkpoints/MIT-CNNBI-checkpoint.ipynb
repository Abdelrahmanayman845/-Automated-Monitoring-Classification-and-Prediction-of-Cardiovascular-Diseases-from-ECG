# %%
import numpy as np
import wfdb
import pywt
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_auc_score
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Dense, Dropout, LSTM
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import numpy as np

# %%
# Load the datasets
X_train = np.load('TEST1/X_train.npy')
y_train = np.load('TEST1/y_train.npy')
X_test = np.load('TEST1/X_test.npy')
y_test = np.load('TEST1/y_test.npy')

# %%
#Plot a signal from each class

import matplotlib.pyplot as plt
import numpy as np

label_mapping = {'N': 0, 'L': 1, 'R': 2, 'A': 3, 'V': 4}


def plot_one_signal_per_class(X, y, label_mapping):
    # Create a reverse mapping from label number to label name
    reverse_label_mapping = {v: k for k, v in label_mapping.items()}
    
    # Find indices of one example per class
    unique_labels = np.unique(y)
    example_indices = []
    for label in unique_labels:
        example_index = np.where(y == label)[0][0]  # Get the index of the first occurrence of each label
        example_indices.append(example_index)
    
    # Plotting
    plt.figure(figsize=(15, 10))
    for i, index in enumerate(example_indices):
        plt.subplot(len(unique_labels), 1, i + 1)
        plt.plot(X[index], label=f"Class: {reverse_label_mapping[y[index]]} (Label {y[index]})")
        plt.legend(loc="upper right")
        plt.tight_layout()
    
    plt.show()


plot_one_signal_per_class(X_train, y_train, label_mapping)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9268\4244235824.py:24: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %%
# Build the model
model = tf.keras.Sequential([
    tf.keras.layers.Conv1D(8, 5, activation='relu', padding='same', input_shape=(X_train.shape[1], 1)),
    tf.keras.layers.MaxPooling1D(2),
    tf.keras.layers.Conv1D(16, 5, activation='relu', padding='same'),
    tf.keras.layers.MaxPooling1D(2),
    tf.keras.layers.Conv1D(32, 5, activation='relu', padding='same'),
    tf.keras.layers.MaxPooling1D(2),
    tf.keras.layers.Conv1D(64, 5, activation='relu', padding='same'),
    tf.keras.layers.MaxPooling1D(2),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128, return_sequences=False)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(5, activation='softmax')
])
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Convert labels to numpy arrays if they aren't already
y_train = np.array(y_train)
y_test = np.array(y_test)


if len(X_train.shape) == 2:
    X_train = np.expand_dims(X_train, axis=-1)  # Add a channel dimension, if necessary
if len(X_test.shape) == 2:
    X_test = np.expand_dims(X_test, axis=-1)  # Add a channel dimension, if necessary

# Print the shapes of the dataset
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (20193, 1080, 1)
# y_train shape: (20193,)
# X_test shape: (8655, 1080, 1)
# y_test shape: (8655,)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
# Train the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
early_stopping = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)
checkpoint_path = 'MODElS/CNNBILSTM.keras'
checkpoint = ModelCheckpoint(checkpoint_path, monitor='val_loss', save_best_only=True, mode='min')

history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=64, verbose=1, callbacks=[early_stopping , checkpoint])

# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=1)
print(f"Test Accuracy: {test_accuracy}")
# Out:
# Epoch 1/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 16s 41ms/step - accuracy: 0.7760 - loss: 0.8566 - val_accuracy: 0.7991 - val_loss: 0.5754
# Epoch 2/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.8137 - loss: 0.5441 - val_accuracy: 0.8468 - val_loss: 0.4116
# Epoch 3/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.8884 - loss: 0.3287 - val_accuracy: 0.9042 - val_loss: 0.2602
# Epoch 4/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 13s 40ms/step - accuracy: 0.9373 - loss: 0.1961 - val_accuracy: 0.9507 - val_loss: 0.1468
# Epoch 5/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9571 - loss: 0.1339 - val_accuracy: 0.9650 - val_loss: 0.1136
# Epoch 6/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9649 - loss: 0.1085 - val_accuracy: 0.9680 - val_loss: 0.1022
# Epoch 7/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9540 - loss: 0.1405 - val_accuracy: 0.9680 - val_loss: 0.0873
# Epoch 8/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9718 - loss: 0.0800 - val_accuracy: 0.9722 - val_loss: 0.0794
# Epoch 9/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9774 - loss: 0.0703 - val_accuracy: 0.9450 - val_loss: 0.1676
# Epoch 10/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9724 - loss: 0.0780 - val_accuracy: 0.9725 - val_loss: 0.0822
# Epoch 11/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9821 - loss: 0.0521 - val_accuracy: 0.9763 - val_loss: 0.0733
# Epoch 12/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9861 - loss: 0.0428 - val_accuracy: 0.9777 - val_loss: 0.0722
# Epoch 13/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9855 - loss: 0.0402 - val_accuracy: 0.9744 - val_loss: 0.0845
# Epoch 14/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9841 - loss: 0.0455 - val_accuracy: 0.9765 - val_loss: 0.0711
# Epoch 15/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9878 - loss: 0.0361 - val_accuracy: 0.9778 - val_loss: 0.0697
# Epoch 16/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9892 - loss: 0.0323 - val_accuracy: 0.9761 - val_loss: 0.0740
# Epoch 17/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9868 - loss: 0.0375 - val_accuracy: 0.9763 - val_loss: 0.0799
# Epoch 18/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9911 - loss: 0.0268 - val_accuracy: 0.9778 - val_loss: 0.0813
# Epoch 19/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9923 - loss: 0.0216 - val_accuracy: 0.9755 - val_loss: 0.0817
# Epoch 20/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9917 - loss: 0.0278 - val_accuracy: 0.9763 - val_loss: 0.0838
# Epoch 21/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9932 - loss: 0.0195 - val_accuracy: 0.9741 - val_loss: 0.0912
# Epoch 22/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9904 - loss: 0.0290 - val_accuracy: 0.9763 - val_loss: 0.0844
# Epoch 23/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9912 - loss: 0.0300 - val_accuracy: 0.9814 - val_loss: 0.0761
# Epoch 24/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9938 - loss: 0.0197 - val_accuracy: 0.9797 - val_loss: 0.0750
# Epoch 25/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9934 - loss: 0.0179 - val_accuracy: 0.9774 - val_loss: 0.0918
# Epoch 26/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9918 - loss: 0.0242 - val_accuracy: 0.9786 - val_loss: 0.0806
# Epoch 27/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9942 - loss: 0.0202 - val_accuracy: 0.9794 - val_loss: 0.0865
# Epoch 28/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9968 - loss: 0.0116 - val_accuracy: 0.9805 - val_loss: 0.0899
# Epoch 29/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9971 - loss: 0.0092 - val_accuracy: 0.9744 - val_loss: 0.1306
# Epoch 30/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9867 - loss: 0.0441 - val_accuracy: 0.9777 - val_loss: 0.0854
# Epoch 31/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9958 - loss: 0.0108 - val_accuracy: 0.9807 - val_loss: 0.0838
# Epoch 32/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9968 - loss: 0.0118 - val_accuracy: 0.9800 - val_loss: 0.0858
# Epoch 33/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9969 - loss: 0.0109 - val_accuracy: 0.9813 - val_loss: 0.0992
# Epoch 34/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9968 - loss: 0.0111 - val_accuracy: 0.9658 - val_loss: 0.1938
# Epoch 35/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9943 - loss: 0.0202 - val_accuracy: 0.9792 - val_loss: 0.0999
# Epoch 36/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9947 - loss: 0.0181 - val_accuracy: 0.9807 - val_loss: 0.0867
# Epoch 37/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9972 - loss: 0.0067 - val_accuracy: 0.9798 - val_loss: 0.1035
# Epoch 38/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9962 - loss: 0.0120 - val_accuracy: 0.9792 - val_loss: 0.0971
# Epoch 39/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9977 - loss: 0.0069 - val_accuracy: 0.9760 - val_loss: 0.1201
# Epoch 40/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9955 - loss: 0.0134 - val_accuracy: 0.9816 - val_loss: 0.0941
# Epoch 41/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9976 - loss: 0.0086 - val_accuracy: 0.9794 - val_loss: 0.0940
# Epoch 42/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9984 - loss: 0.0052 - val_accuracy: 0.9817 - val_loss: 0.0924
# Epoch 43/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9966 - loss: 0.0119 - val_accuracy: 0.9795 - val_loss: 0.0910
# Epoch 44/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9972 - loss: 0.0079 - val_accuracy: 0.9829 - val_loss: 0.0966
# Epoch 45/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9982 - loss: 0.0055 - val_accuracy: 0.9812 - val_loss: 0.0849
# Epoch 46/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9966 - loss: 0.0137 - val_accuracy: 0.9811 - val_loss: 0.0922
# Epoch 47/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9982 - loss: 0.0056 - val_accuracy: 0.9832 - val_loss: 0.0879
# Epoch 48/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9991 - loss: 0.0025 - val_accuracy: 0.9805 - val_loss: 0.1069
# Epoch 49/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9980 - loss: 0.0073 - val_accuracy: 0.9783 - val_loss: 0.1246
# Epoch 50/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9974 - loss: 0.0069 - val_accuracy: 0.9831 - val_loss: 0.1001
# Epoch 51/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9989 - loss: 0.0049 - val_accuracy: 0.9792 - val_loss: 0.0951
# Epoch 52/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9953 - loss: 0.0147 - val_accuracy: 0.9804 - val_loss: 0.0881
# Epoch 53/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9967 - loss: 0.0101 - val_accuracy: 0.9805 - val_loss: 0.1042
# Epoch 54/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9984 - loss: 0.0058 - val_accuracy: 0.9813 - val_loss: 0.0994
# Epoch 55/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9973 - loss: 0.0073 - val_accuracy: 0.9816 - val_loss: 0.1113
# Epoch 56/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9986 - loss: 0.0037 - val_accuracy: 0.9789 - val_loss: 0.1124
# Epoch 57/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9971 - loss: 0.0098 - val_accuracy: 0.9815 - val_loss: 0.1195
# Epoch 58/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9987 - loss: 0.0052 - val_accuracy: 0.9831 - val_loss: 0.1033
# Epoch 59/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9981 - loss: 0.0080 - val_accuracy: 0.9828 - val_loss: 0.1217
# Epoch 60/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9980 - loss: 0.0058 - val_accuracy: 0.9807 - val_loss: 0.1046
# Epoch 61/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9994 - loss: 0.0027 - val_accuracy: 0.9688 - val_loss: 0.1527
# Epoch 62/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9949 - loss: 0.0154 - val_accuracy: 0.9839 - val_loss: 0.0966
# Epoch 63/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9976 - loss: 0.0071 - val_accuracy: 0.9829 - val_loss: 0.1014
# Epoch 64/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9974 - loss: 0.0084 - val_accuracy: 0.9811 - val_loss: 0.0951
# Epoch 65/100
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9990 - loss: 0.0026 - val_accuracy: 0.9823 - val_loss: 0.1067
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9745 - loss: 0.0859
# Test Accuracy: 0.9778162837028503

# %%
from tensorflow.keras.models import load_model
loaded_model = load_model(checkpoint_path)

# %%
# Plot training and test accuracies over epochs
import matplotlib.pyplot as plt


acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
epochs = range(1, len(acc) + 1)  # Number of epochs


plt.figure(figsize=(10, 6))
plt.plot(epochs, acc, 'r', label='Training accuracy')  # 'bo' gives blue color and dot markers
plt.plot(epochs, val_acc, 'b', label='Test accuracy')   # 'b' gives solid blue line
plt.title('Training and Test Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
# Generate predictions
y_pred = loaded_model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
# Out:
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step

# %%
# Print classification report
class_report = classification_report(y_test, y_pred_classes, target_names=['N', 'L', 'R', 'A', 'V'])
print("\nClassification Report:\n", class_report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            N       0.99      0.99      0.99      6759
#            L       0.99      0.99      0.99       667
#            R       0.99      0.98      0.98       617
#            A       0.97      0.81      0.88       199
#            V       0.81      0.91      0.85       413
#
#     accuracy                           0.98      8655
#    macro avg       0.95      0.93      0.94      8655
# weighted avg       0.98      0.98      0.98      8655

# %%
# Compute and plot the confusion matrix
cm = confusion_matrix(y_test, y_pred_classes)
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['N', 'L', 'R', 'A', 'V'], yticklabels=['N', 'L', 'R', 'A', 'V'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# %%
# Plot sample signals with true and predicted labels, and display prediction accuracy

label_mapping = {'N': 0, 'L': 1, 'R': 2, 'A': 3, 'V': 4}
def plot_and_predict(X_test, y_test, model, label_mapping, num_samples=10):
    # Ensure num_samples does not exceed length of X_test
    num_samples = min(num_samples, len(X_test))
    
    # Predict the labels
    predictions = model.predict(X_test)
    predicted_labels = np.argmax(predictions, axis=1)
    
    # Count correct and incorrect predictions
    correct = np.sum(predicted_labels == y_test)
    incorrect = len(y_test) - correct
    
    # Reverse label mapping for easy plotting
    reverse_label_mapping = {v: k for k, v in label_mapping.items()}
    
    # Start plotting
    fig, axes = plt.subplots(num_samples, 1, figsize=(10, num_samples * 2))
    if num_samples == 1:
        axes = [axes]  # Make it iterable

    for i, ax in enumerate(axes):
        signal = X_test[i].flatten()  # Flatten the 2D signal to 1D for plotting
        true_label = reverse_label_mapping.get(y_test[i], 'Unknown')
        predicted_label = reverse_label_mapping.get(predicted_labels[i], 'Unknown')
        ax.plot(signal, label=f'True: {true_label}, Predicted: {predicted_label}')
        ax.legend()
        ax.set_title(f'Signal {i+1}')
        ax.set_xlabel('Time')
        ax.set_ylabel('Amplitude')
    
    plt.tight_layout()
    plt.show()
    
    print(f"Correct Predictions: {correct}")
    print(f"Incorrect Predictions: {incorrect}")


plot_and_predict(X_test, y_test, loaded_model, label_mapping, num_samples=20)
# Out:
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step
# Correct Predictions: 8463
# Incorrect Predictions: 192
