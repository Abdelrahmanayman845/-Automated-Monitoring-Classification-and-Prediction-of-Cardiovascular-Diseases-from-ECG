# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Input, Flatten, Dense, Conv2D, MaxPooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
import os
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_auc_score
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Flatten
from tensorflow.keras.models import Sequential
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load the reshaped datasets
X_train_resized = np.load('/content/drive/MyDrive/PHYSIODATA/X_train_resized.npy')
X_test_resized = np.load('/content/drive/MyDrive/PHYSIODATA/X_test_resized.npy')
y_train = np.load('/content/drive/MyDrive/PHYSIODATA/y_train_resized.npy')
y_test = np.load('/content/drive/MyDrive/PHYSIODATA/y_test_resized.npy')

# %%
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.applications.inception_v3 import preprocess_input as inception_preprocess_input

# Preprocess the data
X_train_resized = inception_preprocess_input(np.repeat(X_train_resized, 3, axis=-1))
X_test_resized = inception_preprocess_input(np.repeat(X_test_resized, 3, axis=-1))

# %%
# Define the InceptionV3 model
height, width, channels = 150, 150, 1
base_model_inception = InceptionV3(weights='imagenet', include_top=False, input_shape=(height, width, 3))
x = base_model_inception.output
x = Flatten()(x)
x = Dense(64, activation='relu')(x)
predictions = Dense(5, activation='softmax')(x)
model_inception = Model(inputs=base_model_inception.input, outputs=predictions)

# Freeze the base model layers
for layer in base_model_inception.layers:
    layer.trainable = False

# Compile the model
model_inception.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Define callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=100, restore_best_weights=True)
checkpoint_path = '/content/drive/MyDrive/PHYSIO2D/PHYSIOinception.h5'
checkpoint = ModelCheckpoint(checkpoint_path, monitor='val_accuracy', save_best_only=True, mode='max')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 0s 0us/step

# %%
# Train and evaluate the model
history = model_inception.fit(
    X_train_resized, y_train,
    epochs=400,
    batch_size=64,
    validation_data=(X_test_resized, y_test),
    callbacks=[checkpoint , early_stopping]
)

train_accuracy = model_inception.evaluate(X_train_resized, y_train, verbose=0)[1]
test_accuracy = model_inception.evaluate(X_test_resized, y_test, verbose=0)[1]

print(f"Training Accuracy: {train_accuracy}, Test Accuracy: {test_accuracy}")
# Out:
# Epoch 1/400
# 140/140 [==============================] - ETA: 0s - loss: 1.0187 - accuracy: 0.5599
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 140/140 [==============================] - 16s 61ms/step - loss: 1.0187 - accuracy: 0.5599 - val_loss: 0.8935 - val_accuracy: 0.6109
# Epoch 2/400
# 140/140 [==============================] - 3s 22ms/step - loss: 0.9108 - accuracy: 0.6020 - val_loss: 0.8707 - val_accuracy: 0.5993
# Epoch 3/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.8560 - accuracy: 0.6251 - val_loss: 0.8163 - val_accuracy: 0.6534
# Epoch 4/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.7881 - accuracy: 0.6587 - val_loss: 0.7422 - val_accuracy: 0.6817
# Epoch 5/400
# 140/140 [==============================] - 3s 22ms/step - loss: 0.7500 - accuracy: 0.6795 - val_loss: 0.7644 - val_accuracy: 0.6690
# Epoch 6/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.6957 - accuracy: 0.7100 - val_loss: 0.6664 - val_accuracy: 0.6933
# Epoch 7/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.6449 - accuracy: 0.7306 - val_loss: 0.6293 - val_accuracy: 0.7726
# Epoch 8/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.5883 - accuracy: 0.7649 - val_loss: 0.5505 - val_accuracy: 0.7913
# Epoch 9/400
# 140/140 [==============================] - 3s 21ms/step - loss: 0.5482 - accuracy: 0.7727 - val_loss: 0.6162 - val_accuracy: 0.7539
# Epoch 10/400
# 140/140 [==============================] - 3s 22ms/step - loss: 0.5003 - accuracy: 0.8009 - val_loss: 0.6125 - val_accuracy: 0.7423
# Epoch 11/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.4486 - accuracy: 0.8260 - val_loss: 0.4451 - val_accuracy: 0.8610
# Epoch 12/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.
ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.2765 - val_accuracy: 0.9495
# Epoch 38/400
# 140/140 [==============================] - 3s 22ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.2820 - val_accuracy: 0.9485
# Epoch 39/400
# 140/140 [==============================] - 3s 22ms/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.2867 - val_accuracy: 0.9505
# Epoch 40/400
# 140/140 [==============================] - 3s 22ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.2831 - val_accuracy: 0.9480
# Epoch 41/400
# 140/140 [==============================] - 3s 21ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.2924 - val_accuracy: 0.9485
# Epoch 42/400
# 140/140 [==============================] - 3s 22ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.2931 - val_accuracy: 0.9469
# Epoch 43/400
# 140/140 [==============================] - 3s 22ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.2965 - val_accuracy: 0.9490
# Epoch 44/400
# 140/140 [==============================] - 3s 22ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.3017 - val_accuracy: 0.9495
# Epoch 45/400
# 140/140 [==============================] - 3s 22ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.3036 - val_accuracy: 0.9480
# Epoch 46/400
# 140/140 [==============================] - 3s 21ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.3067 - val_accuracy: 0.9485
# Epoch 47/400
# 140/140 [==============================] - 3s 22ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.3113 - val_accuracy: 0.9510
# Epoch 48/400
# 140/140 [==============================] - 3s 22ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.3140 - val_accuracy: 0.9495
# Epoch 49/400
# 140/140 [==============================] - 3s 22ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.3201 - val_accuracy: 0.9495
# Epoch 50/400
# 140/140 [==============================] - 3s 22ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.3214 - val_accuracy: 0.9490
# Epoch 51/400
# 140/140 [==============================] - 3s 22ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.3280 - val_accuracy: 0.9495
# Epoch 52/400
# 140/140 [==============================] - 3s 22ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.3330 - val_accuracy: 0.9474
# Epoch 53/400
# 140/140 [==============================] - 3s 22ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.3332 - val_accuracy: 0.9495
# Epoch 54/400
# 140/140 [==============================] - 3s 22ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.3329 - val_accuracy: 0.9485
# Epoch 55/400
# 140/140 [==============================] - 3s 22ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.3387 - val_accuracy: 0.9490
# Epoch 56/400
# 140/140 [==============================] - 3s 22ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.3480 - val_accuracy: 0.9500
# Epoch 57/400
# 140/140 [==============================] - 3s 22ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.3466 - val_accuracy: 0.9485
# Epoch 58/400
# 140/140 [==============================] - 3s 22ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.3515 - val_accuracy: 0.9485
# Epoch 59/400
# 140/140 [==============================] - 3s 22ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3504 - val_accuracy: 0.9490
# Epoch 60/400
# 140/140 [==============================] - 3s 22ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.3619 - val_accuracy: 0.9480
# Epoch 61/400
# 140/140 [==============================] - 3s 22ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.3636 - val_accuracy: 0.9490
# Epoch 62/400
# 140/140 [==============================] - 3s 22ms/step - loss: 9.4410e-04 - accuracy: 1.0000 - val_loss: 0.3682 - val_accuracy: 0.9480
# Epoch 63/400
# 140/140 [==============================] - 3s 21ms/step - loss: 8.6427e-04 - accuracy: 1.0000 - val_loss: 0.3703 - val_accuracy: 0.9480
# Epoch 64/400
# 140/140 [==============================] - 3s 22ms/step - loss: 7.9738e-04 - accuracy: 1.0000 - val_loss: 0.3703 - val_accuracy: 0.9490
# Epoch 65/400
# 140/140 [==============================] - 3s 22ms/step - loss: 7.3128e-04 - accuracy: 1.0000 - val_loss: 0.3771 - val_accuracy: 0.9505
# Epoch 66/400
# 140/140 [==============================] - 3s 22ms/step - loss: 6.8433e-04 - accuracy: 1.0000 - val_loss: 0.3796 - val_accuracy: 0.9490
# Epoch 67/400
# 140/140 [==============================] - 3s 22ms/step - loss: 6.0152e-04 - accuracy: 1.0000 - val_loss: 0.3829 - val_accuracy: 0.9490
# Epoch 68/400
# 140/140 [==============================] - 3s 22ms/step - loss: 5.7496e-04 - accuracy: 1.0000 - val_loss: 0.3810 - val_accuracy: 0.9480
# Epoch 69/400
# 140/140 [==============================] - 3s 22ms/step - loss: 5.2175e-04 - accuracy: 1.0000 - val_loss: 0.3876 - val_accuracy: 0.9480
# Epoch 70/400
# 140/140 [==============================] - 3s 21ms/step - loss: 4.9172e-04 - accuracy: 1.0000 - val_loss: 0.3955 - val_accuracy: 0.9490
# Epoch 71/400
# 140/140 [==============================] - 3s 20ms/step - loss: 4.4334e-04 - accuracy: 1.0000 - val_loss: 0.3984 - val_accuracy: 0.9485
# Epoch 125/400
# 140/140 [==============================] - 3s 22ms/step - loss: 6.0257e-06 - accuracy: 1.0000 - val_loss: 0.5681 - val_accuracy: 0.9480
# Epoch 126/400
# 140/140 [==============================] - 3s 22ms/step - loss: 5.3980e-06 - accuracy: 1.0000 - val_loss: 0.5691 - val_accuracy: 0.9469
# Epoch 127/400
# 140/140 [==============================] - 3s 22ms/step - loss: 5.0688e-06 - accuracy: 1.0000 - val_loss: 0.5714 - val_accuracy: 0.9469
# Epoch 128/400
# 140/140 [==============================] - 3s 23ms/step - loss: 4.8298e-06 - accuracy: 1.0000 - val_loss: 0.5730 - val_accuracy: 0.9469
# Training Accuracy: 0.9993261694908142, Test Accuracy: 0.9499747157096863

# %%
import matplotlib.pyplot as plt

# Plot training and validation accuracies over epochs

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
epochs = range(1, len(acc) + 1)  # Number of epochs


plt.figure(figsize=(10, 6))
plt.plot(epochs, acc, 'r', label='Training accuracy')  # 'bo' gives blue color and dot markers
plt.plot(epochs, val_acc, 'b', label='Test accuracy')   # 'b' gives solid blue line
plt.title('Training and Test Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
from tensorflow.keras.models import load_model
model_path = '/content/drive/MyDrive/PHYSIO2D/PHYSIOinception.h5'
loaded_model = load_model(model_path)

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
# Generate predictions
y_pred = loaded_model.predict(X_test_resized)
y_pred_classes = np.argmax(y_pred, axis=1)
# Out:
# 62/62 [==============================] - 2s 12ms/step

# %%
# Print classification report
class_report = classification_report(y_test, y_pred_classes)
print("\nClassification Report:\n", class_report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94       185
#            1       0.95      0.97      0.96      1137
#            2       0.94      0.93      0.94       627
#            3       1.00      0.93      0.97        30
#
#     accuracy                           0.95      1979
#    macro avg       0.96      0.94      0.95      1979
# weighted avg       0.95      0.95      0.95      1979

# %%
# Compute and plot the confusion matrix
cm = confusion_matrix(y_test, y_pred_classes)
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# %%
# Plot sample signals with true and predicted labels, and display prediction accuracy
def plot_and_predict(X_test, y_test, model, num_samples=10, channel=0):

    # Ensure num_samples does not exceed length of X_test
    num_samples = min(num_samples, len(X_test))

    # Predict the labels
    predictions = model.predict(X_test)
    predicted_labels = np.argmax(predictions, axis=1)

    # Count correct and incorrect predictions
    correct = np.sum(predicted_labels == y_test)
    incorrect = len(y_test) - correct



    # Start plotting
    fig, axes = plt.subplots(num_samples, 1, figsize=(10, num_samples * 2))
    if num_samples == 1:
        axes = [axes]  # Make it iterable

    for i, ax in enumerate(axes):
        signal = X_test[i, :, :, channel].flatten()  # Flatten to 1D for plotting
        true_label = [y_test[i]]
        predicted_label = [predicted_labels[i]]
        ax.plot(signal, label=f'True: {true_label}, Predicted: {predicted_label}')
        ax.legend()
        ax.set_title(f'Signal {i+1}')
        ax.set_xlabel('Time')
        ax.set_ylabel('Amplitude')

    plt.tight_layout()
    plt.show()

    print(f"Correct Predictions: {correct}")
    print(f"Incorrect Predictions: {incorrect}")


plot_and_predict(X_test_resized, y_test, loaded_model, num_samples=30)
# Out:
# 62/62 [==============================] - 1s 12ms/step
# Correct Predictions: 1885
# Incorrect Predictions: 94
