# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Input, Flatten, Dense, Conv2D, MaxPooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
import os
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_auc_score
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Flatten
from tensorflow.keras.models import Sequential
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load the reshaped datasets
X_train_resized = np.load('/content/drive/MyDrive/PHYSIODATA/X_train_resized.npy')
X_test_resized = np.load('/content/drive/MyDrive/PHYSIODATA/X_test_resized.npy')
y_train = np.load('/content/drive/MyDrive/PHYSIODATA/y_train_resized.npy')
y_test = np.load('/content/drive/MyDrive/PHYSIODATA/y_test_resized.npy')

# %%
# Preprocess the data
X_train_resized = tf.keras.applications.vgg16.preprocess_input(np.repeat(X_train_resized, 3, axis=-1))
X_test_resized = tf.keras.applications.vgg16.preprocess_input(np.repeat(X_test_resized, 3, axis=-1))

# %%
# Define the ResNet50 model
from tensorflow.keras.applications import ResNet50


base_model_resNet = ResNet50(weights='imagenet', include_top=False, input_shape=(height, width, 3))
x = base_model_resNet.output
x = Flatten()(x)
x = Dense(64, activation='relu')(x)
predictions = Dense(5, activation='softmax')(x)
model_resNet = Model(inputs=base_model_resNet.input, outputs=predictions)

# Freeze the base model layers
for layer in base_model_resNet.layers:
    layer.trainable = False

# Compile the model
model_resNet.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Define callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=100, restore_best_weights=True)
checkpoint_path = '/content/drive/MyDrive/PHYSIO2D/PHYSIOresnet.h5'
checkpoint = ModelCheckpoint(checkpoint_path, monitor='val_accuracy', save_best_only=True, mode='max')

# %%
# Train and evaluate the model
history = model_resNet.fit(
    X_train_resized, y_train,
    epochs=400,
    batch_size=64,
    validation_data=(X_test_resized, y_test),
    callbacks=[checkpoint , early_stopping]
)

train_accuracy = model_resNet.evaluate(X_train_resized, y_train, verbose=0)[1]
test_accuracy = model_resNet.evaluate(X_test_resized, y_test, verbose=0)[1]

print(f"Training Accuracy: {train_accuracy}, Test Accuracy: {test_accuracy}")
# Out:
# Epoch 1/400
# 140/140 [==============================] - 12s 62ms/step - loss: 1.2541 - accuracy: 0.5262 - val_loss: 1.1321 - val_accuracy: 0.5745
# Epoch 2/400
# 140/140 [==============================] - 5s 33ms/step - loss: 0.9574 - accuracy: 0.5830 - val_loss: 0.8522 - val_accuracy: 0.6134
# Epoch 3/400
# 140/140 [==============================] - 5s 32ms/step - loss: 0.8969 - accuracy: 0.6055 - val_loss: 0.8813 - val_accuracy: 0.6160
# Epoch 4/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.8651 - accuracy: 0.6239 - val_loss: 0.8619 - val_accuracy: 0.6114
# Epoch 5/400
# 140/140 [==============================] - 5s 32ms/step - loss: 0.8295 - accuracy: 0.6361 - val_loss: 0.8566 - val_accuracy: 0.6165
# Epoch 6/400
# 140/140 [==============================] - 5s 34ms/step - loss: 0.8174 - accuracy: 0.6459 - val_loss: 0.7923 - val_accuracy: 0.6448
# Epoch 7/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.7846 - accuracy: 0.6508 - val_loss: 1.0179 - val_accuracy: 0.5366
# Epoch 8/400
# 140/140 [==============================] - 6s 45ms/step - loss: 0.8120 - accuracy: 0.6614 - val_loss: 0.7310 - val_accuracy: 0.7009
# Epoch 9/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.7466 - accuracy: 0.6722 - val_loss: 1.0910 - val_accuracy: 0.4851
# Epoch 10/400
# 140/140 [==============================] - 5s 33ms/step - loss: 0.7450 - accuracy: 0.6689 - val_loss: 0.6946 - val_accuracy: 0.7039
# Epoch 11/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.7020 - accuracy: 0.6933 - val_loss: 0.6857 - val_accuracy: 0.6963
# Epoch 12/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.6902 - accuracy: 0.6968 - val_loss: 0.7957 - val_accuracy: 0.6417
# Epoch 13/400
# 140/140 [==============================] - 6s 44ms/step - loss: 0.6903 - accuracy: 0.6935 - val_loss: 0.6705 - val_accuracy: 0.7059
# Epoch 14/400
# 140/140 [==============================] - 5s 33ms/step - loss: 0.6348 - accuracy: 0.7230 - val_loss: 0.6594 - val_accuracy: 0.7160
# Epoch 15/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.6461 - accuracy: 0.7152 - val_loss: 0.6607 - val_accuracy: 0.7049
# Epoch 16/400
# 140/140 [==============================] - 4s 27ms/step - loss: 0.6209 - accuracy: 0.7369 - val_loss: 0.7184 - val_accuracy: 0.6473
# Epoch 17/400
# 140/140 [==============================] - 5s 34ms/step - loss: 0.6366 - accuracy: 0.7241 - val_loss: 0.5906 - val_accuracy: 0.7479
# Epoch 18/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.5964 - accuracy: 0.7430 - val_loss: 0.7532 - val_accuracy: 0.6640
# Epoch 19/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.5575 - accuracy: 0.7631 - val_loss: 0.7390 - val_accuracy: 0.6705
# Epoch 20/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.6099 - accuracy: 0.7375 - val_loss: 0.6288 - val_accuracy: 0.7180
# Epoch 21/400
# 140/140 [==============================] - 6s 43ms/step - loss: 0.5232 - accuracy: 0.7846 - val_loss: 0.5842 - val_accuracy: 0.7524
# Epoch 22/400
# 140/140 [==============================] - 5s 33ms/step - loss: 0.5280 - accuracy: 0.7749 - val_loss: 0.5976 - val_accuracy: 0.7564
# Epoch 23/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.5017 - accuracy: 0.7866 - val_loss: 0.6431 - val_accuracy: 0.6918
# Epoch 24/400
# 140/140 [==============================] - 5s 34ms/step - loss: 0.5220 - accuracy: 0.7800 - val_loss: 0.5564 - val_accuracy: 0.7696
# Epoch 25/400
# 140/140 [==============================] - 5s 34ms/step - loss: 0.5339 - accuracy: 0.7738 - val_loss: 0.5377 - val_accuracy: 0.7736
# Epoch 26/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.5023 - accuracy: 0.7864 - val_loss: 0.5965 - val_accuracy: 0.7731
# Epoch 27/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.5065 - accuracy: 0.7844 - val_loss: 0.5448 - val_accuracy: 0.7655
# Epoch 28/400
# 140/140 [==============================] - 6s 43ms/step - loss: 0.4735 - accuracy: 0.7985 - val_loss: 0.4861 - val_accuracy: 0.8181
# Epoch 29/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.4490 - accuracy: 0.8094 - val_loss: 0.5252 - val_accuracy: 0.7832
# Epoch 30/400
# 140/140 [==============================] - 5s 33ms/step - loss: 0.4306 - accuracy: 0.8201 - val_loss: 0.4571 - val_accuracy: 0.8494
# Epoch 31/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.4606 - accuracy: 0.7994 - val_loss: 0.5529 - val_accuracy: 0.7812
# Epoch 32/400
# 140/140 [==============================] - 5s 34ms/step - loss: 0.3977 - accuracy: 0.8391 - val_loss: 0.4434 - val_accuracy: 0.8504
# Epoch 33/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.3900 - accuracy: 0.8412 - val_loss: 0.6665 - val_accuracy: 0.7231
# Epoch 34/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.4376 - accuracy: 0.8156 - val_loss: 0.5111 - val_accuracy: 0.8024
# Epoch 35/400
# 140/140 [==============================] - 4s 29ms/step - loss: 0.4182 - accuracy: 0.8217 - val_loss: 0.5406 - val_accuracy: 0.7787
# Epoch 36/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.3997 - accuracy: 0.8286 - val_loss: 0.6021 - val_accuracy: 0.7428
# Epoch 37/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.3945 - accuracy: 0.8330 - val_loss: 0.4968 - val_accuracy: 0.7964
# Epoch 38/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.3716 - accuracy: 0.8464 - val_loss: 0.5301 - val_accuracy: 0.7736
# Epoch 39/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.3774 - accuracy: 0.8479 - val_loss: 0.6696 - val_accuracy: 0.7185
# Epoch 40/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.3509 - accuracy: 0.8570 - val_loss: 0.5958 - val_accuracy: 0.7534
# Epoch 41/400
# 140/140 [==============================] - 6s 42ms/step - loss: 0.3438 - accuracy: 0.8622 - val_loss: 0.3985 - val_accuracy: 0.8807
# Epoch 42/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.3060 - accuracy: 0.8799 - val_loss: 0.4554 - val_accuracy: 0.8317
# Epoch 43/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.3482 - accuracy: 0.8577 - val_loss: 0.4106 - val_accuracy: 0.8737
# Epoch 44/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.3009 - accuracy: 0.8805 - val_loss: 0.4175 - val_accuracy: 0.8626
# Epoch 45/400
# 140/140 [==============================] - 6s 41ms/step - loss: 0.2956 - accuracy: 0.8802 - val_loss: 0.3895 - val_accuracy: 0.8818
# Epoch 46/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.3002 - accuracy: 0.8772 - val_loss: 0.4007 - val_accuracy: 0.8807
# Epoch 47/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.2880 - accuracy: 0.8831 - val_loss: 0.6223 - val_accuracy: 0.7706
# Epoch 48/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.3103 - accuracy: 0.8712 - val_loss: 0.4246 - val_accuracy: 0.8671
# Epoch 49/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.3149 - accuracy: 0.8731 - val_loss: 0.4816 - val_accuracy: 0.8348
# Epoch 50/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.2885 - accuracy: 0.8801 - val_loss: 0.4802 - val_accuracy: 0.8231
# Epoch 51/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.2453 - accuracy: 0.9068 - val_loss: 0.4284 - val_accuracy: 0.8696
# Epoch 52/400
# 140/140 [==============================] - 6s 43ms/step - loss: 0.2533 - accuracy: 0.9009 - val_loss: 0.3911 - val_accuracy: 0.8909
# Epoch 53/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.2451 - accuracy: 0.9054 - val_loss: 1.0488 - val_accuracy: 0.6059
# Epoch 54/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.2778 - accuracy: 0.8840 - val_loss: 0.4375 - val_accuracy: 0.8762
# Epoch 55/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.2213 - accuracy: 0.9162 - val_loss: 0.6696 - val_accuracy: 0.7362
# Epoch 56/400
# 140/140 [==============================] - 6s 42ms/step - loss: 0.2582 - accuracy: 0.8969 - val_loss: 0.4018 - val_accuracy: 0.8969
# Epoch 57/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.2696 - accuracy: 0.8936 - val_loss: 0.4942 - val_accuracy: 0.8186
# Epoch 58/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.2762 - accuracy: 0.8829 - val_loss: 0.4262 - val_accuracy: 0.8802
# Epoch 59/400
# 140/140 [==============================] - 5s 34ms/step - loss: 0.2267 - accuracy: 0.9107 - val_loss: 0.3885 - val_accuracy: 0.9005
# Epoch 60/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.2098 - accuracy: 0.9190 - val_loss: 0.8639 - val_accuracy: 0.7802
# Epoch 61/400
# 140/140 [==============================] - 5s 34ms/step - loss: 0.2310 - accuracy: 0.9080 - val_loss: 0.3744 - val_accuracy: 0.9090
# Epoch 62/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.1800 - accuracy: 0.9349 - val_loss: 0.5919 - val_accuracy: 0.7782
# Epoch 63/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.2830 - accuracy: 0.8827 - val_loss: 0.4277 - val_accuracy: 0.8782
# Epoch 64/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.1676 - accuracy: 0.9403 - val_loss: 0.4239 - val_accuracy: 0.8752
# Epoch 65/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.1832 - accuracy: 0.9317 - val_loss: 0.4268 - val_accuracy: 0.8762
# Epoch 66/400
# 140/140 [==============================] - 4s 27ms/step - loss: 0.1966 - accuracy: 0.9219 - val_loss: 0.4170 - val_accuracy: 0.8934
# Epoch 67/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.1540 - accuracy: 0.9447 - val_loss: 0.5519 - val_accuracy: 0.8257
# Epoch 68/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.1777 - accuracy: 0.9356 - val_loss: 0.3920 - val_accuracy: 0.9090
# Epoch 69/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.1603 - accuracy: 0.9427 - val_loss: 0.4783 - val_accuracy: 0.8656
# Epoch 70/400
# 140/140 [==============================] - 6s 41ms/step - loss: 0.1949 - accuracy: 0.9214 - val_loss: 0.3746 - val_accuracy: 0.9192
# Epoch 71/400
# 140/140 [==============================] - 5s 33ms/step - loss: 0.1426 - accuracy: 0.9515 - val_loss: 0.3857 - val_accuracy: 0.9217
# Epoch 72/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.1850 - accuracy: 0.9292 - val_loss: 0.6474 - val_accuracy: 0.7888
# Epoch 73/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.1937 - accuracy: 0.9215 - val_loss: 0.8465 - val_accuracy: 0.7044
# Epoch 74/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.1870 - accuracy: 0.9252 - val_loss: 0.8216 - val_accuracy: 0.7211
# Epoch 75/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.1971 - accuracy: 0.9283 - val_loss: 0.4258 - val_accuracy: 0.9075
# Epoch 76/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.1422 - accuracy: 0.9469 - val_loss: 0.5241 - val_accuracy: 0.8621
# Epoch 77/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.1218 - accuracy: 0.9600 - val_loss: 0.4432 - val_accuracy: 0.8934
# Epoch 78/400
# 140/140 [==============================] - 6s 40ms/step - loss: 0.1177 - accuracy: 0.9618 - val_loss: 0.3874 - val_accuracy: 0.9288
# Epoch 79/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.1209 - accuracy: 0.9591 - val_loss: 0.4080 - val_accuracy: 0.9207
# Epoch 80/400
# 140/140 [==============================] - 4s 27ms/step - loss: 0.2124 - accuracy: 0.9112 - val_loss: 0.6931 - val_accuracy: 0.8267
# Epoch 81/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.1417 - accuracy: 0.9461 - val_loss: 0.3945 - val_accuracy: 0.9288
# Epoch 82/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.1309 - accuracy: 0.9492 - val_loss: 0.9251 - val_accuracy: 0.7069
# Epoch 83/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.1829 - accuracy: 0.9349 - val_loss: 0.4686 - val_accuracy: 0.8954
# Epoch 84/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.1584 - accuracy: 0.9455 - val_loss: 0.5309 - val_accuracy: 0.8595
# Epoch 85/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.1067 - accuracy: 0.9665 - val_loss: 0.5577 - val_accuracy: 0.8585
# Epoch 86/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.1365 - accuracy: 0.9501 - val_loss: 0.5770 - val_accuracy: 0.8514
# Epoch 87/400
# 140/140 [==============================] - 4s 27ms/step - loss: 0.1124 - accuracy: 0.9605 - val_loss: 0.6384 - val_accuracy: 0.8358
# Epoch 88/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.0946 - accuracy: 0.9659 - val_loss: 0.4272 - val_accuracy: 0.9262
# Epoch 89/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.1211 - accuracy: 0.9531 - val_loss: 0.6891 - val_accuracy: 0.8176
# Epoch 90/400
# 140/140 [==============================] - 6s 41ms/step - loss: 0.1391 - accuracy: 0.9441 - val_loss: 0.4168 - val_accuracy: 0.9293
# Epoch 91/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.0645 - accuracy: 0.9832 - val_loss: 0.4455 - val_accuracy: 0.9217
# Epoch 92/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.1353 - accuracy: 0.9472 - val_loss: 0.4589 - val_accuracy: 0.9040
# Epoch 93/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.0778 - accuracy: 0.9768 - val_loss: 0.4989 - val_accuracy: 0.8893
# Epoch 94/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.0644 - accuracy: 0.9827 - val_loss: 1.0269 - val_accuracy: 0.7049
# Epoch 95/400
# 140/140 [==============================] - 6s 40ms/step - loss: 0.2370 - accuracy: 0.9182 - val_loss: 0.4138 - val_accuracy: 0.9378
# Epoch 96/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.1025 - accuracy: 0.9666 - val_loss: 0.5258 - val_accuracy: 0.9075
# Epoch 97/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.1032 - accuracy: 0.9613 - val_loss: 0.4401 - val_accuracy: 0.9267
# Epoch 98/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.0733 - accuracy: 0.9770 - val_loss: 0.4254 - val_accuracy: 0.9368
# Epoch 99/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.0775 - accuracy: 0.9736 - val_loss: 0.7062 - val_accuracy: 0.8262
# Epoch 100/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.1171 - accuracy: 0.9544 - val_loss: 0.4422 - val_accuracy: 0.9348
# Epoch 101/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.0955 - accuracy: 0.9661 - val_loss: 0.4263 - val_accuracy: 0.9353
# Epoch 102/400
# 140/140 [==============================] - 6s 41ms/step - loss: 0.0696 - accuracy: 0.9783 - val_loss: 0.4295 - val_accuracy: 0.9429
# Epoch 103/400
# 140/140 [==============================] - 5s 34ms/step - loss: 0.0431 - accuracy: 0.9925 - val_loss: 0.4331 - val_accuracy: 0.9449
# Epoch 104/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.0574 - accuracy: 0.9833 - val_loss: 0.6107 - val_accuracy: 0.8439
# Epoch 105/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.1200 - accuracy: 0.9565 - val_loss: 0.4656 - val_accuracy: 0.9318
# Epoch 106/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.2514 - accuracy: 0.9378 - val_loss: 0.4759 - val_accuracy: 0.9131
# Epoch 107/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.1285 - accuracy: 0.9568 - val_loss: 0.4685 - val_accuracy: 0.9202
# Epoch 108/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.0681 - accuracy: 0.9794 - val_loss: 0.4656 - val_accuracy: 0.9277
# Epoch 109/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.0762 - accuracy: 0.9778 - val_loss: 0.6245 - val_accuracy: 0.8676
# Epoch 110/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.0699 - accuracy: 0.9768 - val_loss: 0.7322 - val_accuracy: 0.8358
# Epoch 111/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.1084 - accuracy: 0.9614 - val_loss: 0.4662 - val_accuracy: 0.9378
# Epoch 112/400
# 140/140 [==============================] - 6s 40ms/step - loss: 0.0915 - accuracy: 0.9678 - val_loss: 0.4666 - val_accuracy: 0.9454
# Epoch 113/400
# 140/140 [==============================] - 5s 33ms/step - loss: 0.0385 - accuracy: 0.9928 - val_loss: 0.4535 - val_accuracy: 0.9464
# Epoch 114/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.0321 - accuracy: 0.9952 - val_loss: 0.4539 - val_accuracy: 0.9449
# Epoch 115/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.0266 - accuracy: 0.9979 - val_loss: 0.5627 - val_accuracy: 0.8944
# Epoch 116/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.0860 - accuracy: 0.9695 - val_loss: 0.4490 - val_accuracy: 0.9444
# Epoch 117/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.0425 - accuracy: 0.9889 - val_loss: 0.4745 - val_accuracy: 0.9454
# Epoch 118/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.4010 - accuracy: 0.8868 - val_loss: 0.4715 - val_accuracy: 0.9313
# Epoch 119/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.1348 - accuracy: 0.9531 - val_loss: 0.4776 - val_accuracy: 0.9424
# Epoch 120/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.0357 - accuracy: 0.9933 - val_loss: 0.4767 - val_accuracy: 0.9409
# Epoch 121/400
# 140/140 [==============================] - 6s 44ms/step - loss: 0.0277 - accuracy: 0.9978 - val_loss: 0.4744 - val_accuracy: 0.9495
# Epoch 122/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.0283 - accuracy: 0.9951 - val_loss: 0.4693 - val_accuracy: 0.9439
# Epoch 123/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.0240 - accuracy: 0.9975 - val_loss: 0.4644 - val_accuracy: 0.9459
# Epoch 124/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.0288 - accuracy: 0.9951 - val_loss: 0.4524 - val_accuracy: 0.9485
# Epoch 125/400
# 140/140 [==============================] - 6s 41ms/step - loss: 0.0246 - accuracy: 0.9974 - val_loss: 0.4788 - val_accuracy: 0.9500
# Epoch 126/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.0334 - accuracy: 0.9925 - val_loss: 0.4794 - val_accuracy: 0.9469
# Epoch 127/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.0433 - accuracy: 0.9872 - val_loss: 0.5271 - val_accuracy: 0.9272
# Epoch 128/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.2427 - accuracy: 0.9228 - val_loss: 0.4883 - val_accuracy: 0.9444
# Epoch 129/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.0377 - accuracy: 0.9901 - val_loss: 0.4704 - val_accuracy: 0.9464
# Epoch 130/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.0184 - accuracy: 0.9991 - val_loss: 0.4834 - val_accuracy: 0.9490
# Epoch 131/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.0240 - accuracy: 0.9966 - val_loss: 0.5105 - val_accuracy: 0.9348
# Epoch 132/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.0281 - accuracy: 0.9943 - val_loss: 0.4834 - val_accuracy: 0.9480
# Epoch 133/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.0248 - accuracy: 0.9952 - val_loss: 0.4844 - val_accuracy: 0.9500
# Epoch 134/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.0158 - accuracy: 0.9996 - val_loss: 0.4758 - val_accuracy: 0.9459
# Epoch 135/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.0313 - accuracy: 0.9917 - val_loss: 0.6306 - val_accuracy: 0.8929
# Epoch 136/400
# 140/140 [==============================] - 4s 29ms/step - loss: 0.0404 - accuracy: 0.9893 - val_loss: 0.5412 - val_accuracy: 0.9353
# Epoch 137/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.4392 - accuracy: 0.9127 - val_loss: 0.7553 - val_accuracy: 0.8560
# Epoch 138/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.0991 - accuracy: 0.9663 - val_loss: 0.4842 - val_accuracy: 0.9429
# Epoch 139/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.0701 - accuracy: 0.9756 - val_loss: 0.5011 - val_accuracy: 0.9419
# Epoch 140/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.0332 - accuracy: 0.9944 - val_loss: 0.4797 - val_accuracy: 0.9469
# Epoch 141/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.0893 - accuracy: 0.9689 - val_loss: 0.8152 - val_accuracy: 0.8176
# Epoch 142/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.0474 - accuracy: 0.9871 - val_loss: 0.4745 - val_accuracy: 0.9469
# Epoch 143/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.0258 - accuracy: 0.9962 - val_loss: 0.5096 - val_accuracy: 0.9414
# Epoch 144/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.0190 - accuracy: 0.9989 - val_loss: 0.5176 - val_accuracy: 0.9449
# Epoch 145/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.0220 - accuracy: 0.9975 - val_loss: 0.4798 - val_accuracy: 0.9474
# Epoch 146/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.0206 - accuracy: 0.9989 - val_loss: 0.5833 - val_accuracy: 0.9126
# Epoch 147/400
# 140/140 [==============================] - 4s 27ms/step - loss: 0.1347 - accuracy: 0.9507 - val_loss: 0.5491 - val_accuracy: 0.9131
# Epoch 148/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.0561 - accuracy: 0.9837 - val_loss: 0.5027 - val_accuracy: 0.9434
# Epoch 149/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.0204 - accuracy: 0.9980 - val_loss: 0.4834 - val_accuracy: 0.9474
# Epoch 150/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.0130 - accuracy: 1.0000 - val_loss: 0.4978 - val_accuracy: 0.9480
# Epoch 151/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.0134 - accuracy: 0.9999 - val_loss: 0.4974 - val_accuracy: 0.9490
# Epoch 152/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.0146 - accuracy: 0.9998 - val_loss: 0.5016 - val_accuracy: 0.9469
# Epoch 153/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.2412 - accuracy: 0.9506 - val_loss: 2.3876 - val_accuracy: 0.5816
# Epoch 154/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.5645 - accuracy: 0.8466 - val_loss: 0.5691 - val_accuracy: 0.9121
# Epoch 155/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.0337 - accuracy: 0.9936 - val_loss: 0.4822 - val_accuracy: 0.9439
# Epoch 156/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.0187 - accuracy: 0.9992 - val_loss: 0.4721 - val_accuracy: 0.9469
# Epoch 157/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.0139 - accuracy: 1.0000 - val_loss: 0.4758 - val_accuracy: 0.9485
# Epoch 158/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.0127 - accuracy: 0.9999 - val_loss: 0.4730 - val_accuracy: 0.9480
# Epoch 159/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.0124 - accuracy: 0.9999 - val_loss: 0.4727 - val_accuracy: 0.9480
# Epoch 160/400
# 140/140 [==============================] - 4s 28ms/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.4754 - val_accuracy: 0.9490
# Epoch 161/400
# 140/140 [==============================] - 4s 29ms/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 0.4790 - val_accuracy: 0.9490
# Training Accuracy: 0.9557502269744873, Test Accuracy: 0.9085396528244019

# %%
from tensorflow.keras.models import load_model
model_path = '/content/drive/MyDrive/PHYSIO2D/PHYSIOresnet.h5'
loaded_model = load_model(model_path)

# %%
# Plot training and validation accuracies over epochs
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
epochs = range(1, len(acc) + 1)  # Number of epochs

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(epochs, acc, 'r', label='Training accuracy')  # 'bo' gives blue color and dot markers
plt.plot(epochs, val_acc, 'b', label='Test accuracy')   # 'b' gives solid blue line
plt.title('Training and Test Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
# Generate predictions
y_pred = loaded_model.predict(X_test_resized)
y_pred_classes = np.argmax(y_pred, axis=1)
# Out:
# 62/62 [==============================] - 2s 12ms/step

# %%
# Print classification report
class_report = classification_report(y_test, y_pred_classes)
print("\nClassification Report:\n", class_report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93       185
#            1       0.95      0.97      0.96      1137
#            2       0.95      0.92      0.94       627
#            3       0.97      0.93      0.95        30
#
#     accuracy                           0.95      1979
#    macro avg       0.95      0.94      0.94      1979
# weighted avg       0.95      0.95      0.95      1979

# %%
# Compute and plot the confusion matrix
cm = confusion_matrix(y_test, y_pred_classes)
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# %%
# Plot sample signals with true and predicted labels, and display prediction accuracy
def plot_and_predict(X_test, y_test, model, num_samples=10, channel=0):

    # Ensure num_samples does not exceed length of X_test
    num_samples = min(num_samples, len(X_test))

    # Predict the labels
    predictions = model.predict(X_test)
    predicted_labels = np.argmax(predictions, axis=1)

    # Count correct and incorrect predictions
    correct = np.sum(predicted_labels == y_test)
    incorrect = len(y_test) - correct



    # Start plotting
    fig, axes = plt.subplots(num_samples, 1, figsize=(10, num_samples * 2))
    if num_samples == 1:
        axes = [axes]  # Make it iterable

    for i, ax in enumerate(axes):
        signal = X_test[i, :, :, channel].flatten()  # Flatten to 1D for plotting
        true_label = [y_test[i]]
        predicted_label = [predicted_labels[i]]
        ax.plot(signal, label=f'True: {true_label}, Predicted: {predicted_label}')
        ax.legend()
        ax.set_title(f'Signal {i+1}')
        ax.set_xlabel('Time')
        ax.set_ylabel('Amplitude')

    plt.tight_layout()
    plt.show()

    print(f"Correct Predictions: {correct}")
    print(f"Incorrect Predictions: {incorrect}")


plot_and_predict(X_test_resized, y_test, loaded_model, num_samples=30)
# Out:
# 62/62 [==============================] - 1s 12ms/step
# Correct Predictions: 1880
# Incorrect Predictions: 99
